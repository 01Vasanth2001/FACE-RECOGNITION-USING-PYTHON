# %%
pip install bing_image_downloader
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bing_image_downloader import downloader

# %%
downloader.download("kamal hassan face",10,"C:/Users/ai9/Documents/30images/kamal")
# Out:
# [%] Downloading Images to C:\Users\ai9\Documents\30images\kamal\kamal hassan face
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i1.wp.com/sifetbabo.com/wp-content/uploads/2019/07/Kamal-Haasan.jpg?fit=1920%2C1080&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://2.bp.blogspot.com/-wgz1o48wI9w/TyhhnuZiWbI/AAAAAAAAIQY/kGo5_iBMJhI/s1600/kamal-hassan4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://static.moviecrow.com/marquee/is-this-kamal-hassans-new-look-for-indian2/133775_thumb_665.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.dnaindia.com/sites/default/files/styles/full/public/2018/03/01/656723-612458-kamal-haasan-070417.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://surfolks.com/wp-content/uploads/2016/08/Actor-Kamal-Hassan-Stills-1024x809.jpg
# ...

# %%
downloader.download("rahman",10,"C:/Users/ai9/Documents/30images/rahman")
# Out:
# [%] Downloading Images to C:\Users\ai9\Documents\30images\rahman\rahman
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.themoviedb.org/t/p/w600_and_h900_bestv2/mODBOj6M2EpwR5imDACsjbCYLt0.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://images.indiawords.com/wp-content/uploads/2018/07/sad-look-pics-of-Rahman.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.newsbugz.com/wp-content/uploads/2018/11/Actor-Rahman-Images-10.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://media.indiatimes.in/media/content/2013/Jul/ar_rahman_1375260847_540x540.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://images.tamilscraps.com/wp-content/uploads/2018/01/Rahman-malayalam-movie-still.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://images.tamilscraps.com/wp-content/uploads/2018/01/latest-pics-of-Rahman.jpg
# ...

# %%
downloader.download("yuvan",10,"C:/Users/ai9/Documents/30images/yuvan")
# Out:
# [%] Downloading Images to C:\Users\ai9\Documents\30images\yuvan\yuvan
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 10 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.wikimylinks.com/wp-content/uploads/2020/04/yuvan-actor-wiki-biography-age-movies-family-images_5e8bb873d18eb.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://3.bp.blogspot.com/-yTBeSkP8Tug/Tdax2bTGhFI/AAAAAAAAAvU/EN8zxJeNZ-E/s1600/Yuvan-shankar-raja-Think-Music-50th-Album-14.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i0.wp.com/www.newsbugz.com/wp-content/uploads/2018/12/Yuvan-Images6.jpg?resize=700%2C1054&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://1.bp.blogspot.com/-dq4cSLW1kIY/Uvt1yAwGM5I/AAAAAAACLww/S4ZLlviTfnw/s1600/Yuvan+Shankar+Raja+Converted+To+Islam.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i1.wp.com/www.newsbugz.com/wp-content/uploads/2018/12/Yuvan-Images2.jpg?resize=700%2C1050&amp;ssl=1
# ...

# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
kamal=os.listdir("C:/Users/ai9/Documents/30images/kamal/")
rahman=os.listdir("C:/Users/ai9/Documents/30images/rahman")
yuvan=os.listdir("C:/Users/ai9/Documents/30images/yuvan")

# %%
limit=10
kamal_images=[None]*limit
rahman_images=[None]*limit
yuvan_images=[None]*limit

# %%
j=0
for i in kamal:
    if(j<limit):
        kamal_images[j]=imread("C:/Users/ai9/Documents/30images/kamal/"+i)
        j+=1
    else:
        break

# %%
j=0
for i in rahman:
    if(j<limit):
        rahman_images[j]=imread("C:/Users/ai9/Documents/30images/rahman/"+i)
        j+=1
    else:
        break

# %%
j=0
for i in yuvan:
    if(j<limit):
        yuvan_images[j]=imread("C:/Users/ai9/Documents/30images/yuvan/"+i)
        j+=1
    else:
        break

# %%
imshow(rahman_images[5])

# %%
kamal_gray=[None]*limit
rahman_gray=[None]*limit
yuvan_gray=[None]*limit

# %%
j=0
for i in kamal:
    if(j<limit):
        kamal_gray[j]=rgb2gray(kamal_images[j][:,:,:3])
        j+=1
    else:
        break

# %%
kamal_gray[5].shape
# Out:
# (1500, 1201)

# %%
j=0
for i in rahman:
    if(j<limit):
        rahman_gray[j]=rgb2gray(rahman_images[j][:,:,:3])
        j+=1
    else:
        break

# %%
rahman_gray[6].shape
# Out:
# (168, 300)

# %%
j=0
for i in yuvan:
    if(j<limit):
        yuvan_gray[j]=rgb2gray(yuvan_images[j][:,:,:3])
        j+=1
    else:
        break

# %%
yuvan_gray[7].shape
# Out:
# (275, 183)

# %%
for j in range(10):
    rl=kamal_gray[j]
    kamal_gray[j]=resize(rl,(512,512))
    
for j in range(10):
    rl=rahman_gray[j]
    rahman_gray[j]=resize(rl,(512,512))
    
for j in range(10):
    rl=yuvan_gray[j]
    yuvan_gray[j]=resize(rl,(512,512))

# %%
imshow(kamal_gray[8])

# %%
len_of_images_kamal=len(kamal_gray)
len_of_images_kamal
# Out:
# 10

# %%
image_size_kamal=kamal_gray[1].shape
image_size_kamal
# Out:
# (512, 512)

# %%
flatten_size_kamal=image_size_kamal[0]*image_size_kamal[1]
flatten_size_kamal
# Out:
# 262144

# %%
kamal_gray=np.dstack(kamal_gray)

# %%
kamal_gray.shape
# Out:
# (512, 512, 10)

# %%
kamal_gray=np.rollaxis(kamal_gray,axis=2,start=0)
kamal_gray.shape
# Out:
# (10, 512, 512)

# %%
kamal_gray=kamal_gray.reshape(len_of_images_kamal,flatten_size_kamal)
kamal_gray.shape
# Out:
# (10, 262144)

# %%
kamal_data=pd.DataFrame(kamal_gray)
kamal_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.026886  0.027058  0.030179  0.030722  0.027950  0.026887  0.026885
# 1  0.806480  0.809597  0.809712  0.810310  0.810363  0.813212  0.813633
# 2  0.569096  0.583299  0.476428  0.466244  0.445340  0.425063  0.514692
# 3  0.490589  0.500763  0.504643  0.502471  0.508520  0.518747  0.523723
# 4  0.673447  0.673447  0.673447  0.673447  0.673447  0.673447  0.673447
# 5  0.157204  0.157204  0.157204  0.157204  0.157204  0.157204  0.157575
# 6  0.003661  0.003661  0.003919  0.003920  0.005611  0.005828  0.009249
# 7  0.529355  0.529299  0.529299  0.529299  0.529299  0.529260  0.529291
# 8  0.720435  0.722192  0.728126  0.736417  0.740776  0.737495  0.744497
# 9  0.305649  0.301540  0.295649  0.291147  0.287663  0.287273  0.289521
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.026885  0.026885  0.026885  ...  0.126063  0.126071  0.126055  0.122971
# ...

# %%
kamal_data["label"]="kamal"
kamal_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.026886  0.027058  0.030179  0.030722  0.027950  0.026887  0.026885
# 1  0.806480  0.809597  0.809712  0.810310  0.810363  0.813212  0.813633
# 2  0.569096  0.583299  0.476428  0.466244  0.445340  0.425063  0.514692
# 3  0.490589  0.500763  0.504643  0.502471  0.508520  0.518747  0.523723
# 4  0.673447  0.673447  0.673447  0.673447  0.673447  0.673447  0.673447
# 5  0.157204  0.157204  0.157204  0.157204  0.157204  0.157204  0.157575
# 6  0.003661  0.003661  0.003919  0.003920  0.005611  0.005828  0.009249
# 7  0.529355  0.529299  0.529299  0.529299  0.529299  0.529260  0.529291
# 8  0.720435  0.722192  0.728126  0.736417  0.740776  0.737495  0.744497
# 9  0.305649  0.301540  0.295649  0.291147  0.287663  0.287273  0.289521
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.026885  0.026885  0.026885  ...  0.126071  0.126055  0.122971  0.115427
# ...

# %%
len_of_images_rahman=len(rahman_gray)
len_of_images_rahman
# Out:
# 10

# %%
image_size_rahman=rahman_gray[4].shape
image_size_rahman
# Out:
# (512, 512)

# %%
for i in range(len_of_images_kamal):
    kamal_gray[i]=np.ndarray.flatten(kamal_gray[i]).reshape(flatten_size_kamal,1)

# %%
rahman_gray=np.dstack(rahman_gray)

# %%
rahman_gray.shape
# Out:
# (512, 512, 10)

# %%
rahman_gray=np.rollaxis(rahman_gray,axis=2,start=0)
rahman_gray.shape
# Out:
# (10, 512, 512)

# %%
rahman_gray=rahman_gray.reshape(len_of_images_rahman,flatten_size_rahman)
rahman_gray.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 rahman_gray=rahman_gray.reshape(len_of_images_rahman,flatten_size_rahman)
#       2 rahman_gray.shape
#
# NameError: name 'flatten_size_rahman' is not defined

# %%
flatten_size_rahman=image_size_rahman[0]*image_size_rahman[1]
flatten_size_rahman
# Out:
# 262144

# %%
rahman_gray=rahman_gray.reshape(len_of_images_rahman,flatten_size_rahman)
rahman_gray.shape
# Out:
# (10, 262144)

# %%
rahman_data=pd.DataFrame(rahman_gray)
rahman_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.431583  0.431583  0.431583  0.431583  0.431940  0.433465  0.434017
# 1  0.843924  0.843924  0.843924  0.843924  0.843924  0.843924  0.843924
# 2  0.891404  0.891154  0.891467  0.891780  0.892484  0.894088  0.895692
# 3  0.353300  0.353300  0.353300  0.353300  0.353300  0.353300  0.353300
# 4  0.347869  0.347159  0.348869  0.350578  0.352199  0.353808  0.356766
# 5  0.029423  0.029423  0.029423  0.029423  0.029423  0.029423  0.029423
# 6  0.431583  0.431583  0.431583  0.431583  0.431940  0.433465  0.434017
# 7  0.495754  0.495984  0.505903  0.516882  0.528785  0.538474  0.546409
# 8  0.426919  0.427143  0.426436  0.425764  0.426440  0.427115  0.430018
# 9  0.772478  0.773956  0.778995  0.784189  0.787989  0.787178  0.778531
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.433693  0.435384  0.437276  ...  0.662635  0.662374  0.661269  0.655130
# ...

# %%
rahman_data["label"]="kamal"
rahman_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.431583  0.431583  0.431583  0.431583  0.431940  0.433465  0.434017
# 1  0.843924  0.843924  0.843924  0.843924  0.843924  0.843924  0.843924
# 2  0.891404  0.891154  0.891467  0.891780  0.892484  0.894088  0.895692
# 3  0.353300  0.353300  0.353300  0.353300  0.353300  0.353300  0.353300
# 4  0.347869  0.347159  0.348869  0.350578  0.352199  0.353808  0.356766
# 5  0.029423  0.029423  0.029423  0.029423  0.029423  0.029423  0.029423
# 6  0.431583  0.431583  0.431583  0.431583  0.431940  0.433465  0.434017
# 7  0.495754  0.495984  0.505903  0.516882  0.528785  0.538474  0.546409
# 8  0.426919  0.427143  0.426436  0.425764  0.426440  0.427115  0.430018
# 9  0.772478  0.773956  0.778995  0.784189  0.787989  0.787178  0.778531
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.433693  0.435384  0.437276  ...  0.662374  0.661269  0.655130  0.651896
# ...

# %%
len_of_images_yuvan=len(yuvan_gray)
len_of_images_yuvan
# Out:
# 10

# %%
image_size_yuvan=yuvan_gray[1].shape
image_size_yuvan
# Out:
# (512, 512)

# %%
flatten_size_yuvan=image_size_yuvan[0]*image_size_yuvan[1]
flatten_size_yuvan
# Out:
# 262144

# %%
for i in range(len_of_images_yuvan):
    yuvan_gray[i]=np.ndarray.flatten(yuvan_gray[i]).reshape(flatten_size_yuvan,1)

# %%
yuvan_gray=np.dstack(yuvan_gray)

# %%
yuvan_gray.shape
# Out:
# (262144, 1, 10)

# %%
yuvan_gray=np.rollaxis(yuvan_gray,axis=2,start=0)
yuvan_gray.shape
# Out:
# (10, 262144, 1)

# %%
yuvan_gray=yuvan_gray.reshape(len_of_images_yuvan,flatten_size_yuvan)
yuvan_gray.shape
# Out:
# (10, 262144)

# %%
yuvan_data=pd.DataFrame(yuvan_gray)
yuvan_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.179448  0.177942  0.179829  0.181717  0.183721  0.185995  0.188269
# 1  0.372036  0.372036  0.372036  0.373526  0.375632  0.375784  0.375577
# 2  0.444835  0.444614  0.443845  0.442375  0.441019  0.440250  0.438710
# 3  0.934367  0.934367  0.934367  0.935428  0.937412  0.938289  0.938289
# 4  0.808424  0.808424  0.808424  0.808424  0.808424  0.808424  0.808424
# 5  0.991584  0.991584  0.991584  0.991584  0.991584  0.991584  0.991584
# 6  0.657962  0.657962  0.657962  0.658490  0.659476  0.661019  0.663002
# 7  0.193926  0.193926  0.193926  0.193926  0.193926  0.193926  0.193926
# 8  0.450365  0.451028  0.446056  0.439818  0.430626  0.421400  0.411997
# 9  0.590958  0.590958  0.590958  0.590958  0.590958  0.590958  0.592355
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.191847  0.196700  0.201554  ...  0.453637  0.452235  0.450834  0.450818
# ...

# %%
yuvan_data["label"]="rahman"
yuvan_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.179448  0.177942  0.179829  0.181717  0.183721  0.185995  0.188269
# 1  0.372036  0.372036  0.372036  0.373526  0.375632  0.375784  0.375577
# 2  0.444835  0.444614  0.443845  0.442375  0.441019  0.440250  0.438710
# 3  0.934367  0.934367  0.934367  0.935428  0.937412  0.938289  0.938289
# 4  0.808424  0.808424  0.808424  0.808424  0.808424  0.808424  0.808424
# 5  0.991584  0.991584  0.991584  0.991584  0.991584  0.991584  0.991584
# 6  0.657962  0.657962  0.657962  0.658490  0.659476  0.661019  0.663002
# 7  0.193926  0.193926  0.193926  0.193926  0.193926  0.193926  0.193926
# 8  0.450365  0.451028  0.446056  0.439818  0.430626  0.421400  0.411997
# 9  0.590958  0.590958  0.590958  0.590958  0.590958  0.590958  0.592355
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.191847  0.196700  0.201554  ...  0.452235  0.450834  0.450818  0.452220
# ...

# %%
actor_1=pd.concat([kamal_data,rahman_data])
actor=pd.concat([actor_1,yuvan_data])
actor
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.026886  0.027058  0.030179  0.030722  0.027950  0.026887  0.026885
# 1  0.806480  0.809597  0.809712  0.810310  0.810363  0.813212  0.813633
# 2  0.569096  0.583299  0.476428  0.466244  0.445340  0.425063  0.514692
# 3  0.490589  0.500763  0.504643  0.502471  0.508520  0.518747  0.523723
# 4  0.673447  0.673447  0.673447  0.673447  0.673447  0.673447  0.673447
# 5  0.157204  0.157204  0.157204  0.157204  0.157204  0.157204  0.157575
# 6  0.003661  0.003661  0.003919  0.003920  0.005611  0.005828  0.009249
# 7  0.529355  0.529299  0.529299  0.529299  0.529299  0.529260  0.529291
# 8  0.720435  0.722192  0.728126  0.736417  0.740776  0.737495  0.744497
# 9  0.305649  0.301540  0.295649  0.291147  0.287663  0.287273  0.289521
# 0  0.431583  0.431583  0.431583  0.431583  0.431940  0.433465  0.434017
# 1  0.843924  0.843924  0.843924  0.843924  0.843924  0.843924  0.843924
# ...

# %%
from sklearn.utils import shuffle
kollywood_indexed=shuffle(actor).reset_index()
kollywood_indexed
# Out:
#     index         0         1         2         3         4         5  \
# 0       8  0.426919  0.427143  0.426436  0.425764  0.426440  0.427115
# 1       8  0.450365  0.451028  0.446056  0.439818  0.430626  0.421400
# 2       2  0.891404  0.891154  0.891467  0.891780  0.892484  0.894088
# 3       6  0.657962  0.657962  0.657962  0.658490  0.659476  0.661019
# 4       4  0.347869  0.347159  0.348869  0.350578  0.352199  0.353808
# 5       5  0.991584  0.991584  0.991584  0.991584  0.991584  0.991584
# 6       7  0.529355  0.529299  0.529299  0.529299  0.529299  0.529260
# 7       9  0.305649  0.301540  0.295649  0.291147  0.287663  0.287273
# 8       1  0.372036  0.372036  0.372036  0.373526  0.375632  0.375784
# 9       0  0.026886  0.027058  0.030179  0.030722  0.027950  0.026887
# 10      2  0.444835  0.444614  0.443845  0.442375  0.441019  0.440250
# 11      2  0.569096  0.583299  0.476428  0.466244  0.445340  0.425063
# ...

# %%
kollywood_actors=kollywood_indexed.drop(['index'],axis=1)
kollywood_actors
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.426919  0.427143  0.426436  0.425764  0.426440  0.427115  0.430018
# 1   0.450365  0.451028  0.446056  0.439818  0.430626  0.421400  0.411997
# 2   0.891404  0.891154  0.891467  0.891780  0.892484  0.894088  0.895692
# 3   0.657962  0.657962  0.657962  0.658490  0.659476  0.661019  0.663002
# 4   0.347869  0.347159  0.348869  0.350578  0.352199  0.353808  0.356766
# 5   0.991584  0.991584  0.991584  0.991584  0.991584  0.991584  0.991584
# 6   0.529355  0.529299  0.529299  0.529299  0.529299  0.529260  0.529291
# 7   0.305649  0.301540  0.295649  0.291147  0.287663  0.287273  0.289521
# 8   0.372036  0.372036  0.372036  0.373526  0.375632  0.375784  0.375577
# 9   0.026886  0.027058  0.030179  0.030722  0.027950  0.026887  0.026885
# 10  0.444835  0.444614  0.443845  0.442375  0.441019  0.440250  0.438710
# 11  0.569096  0.583299  0.476428  0.466244  0.445340  0.425063  0.514692
# ...

# %%
x=kollywood_actors.values[:,:-1]
y=kollywood_actors.values[:,-1]

# %%
x
# Out:
# array([[0.4269191467988257, 0.42714289201773853, 0.42643649639802816,
#         ..., 0.34494563112745097, 0.35340917279411765,
#         0.35072841299019614],
#        [0.45036522499234066, 0.45102823433670347, 0.44605566425398285,
#         ..., 0.9745211764705882, 0.9745211764705882, 0.9745211764705883],
#        [0.891403606558407, 0.8911540240747788, 0.8914668569138471, ...,
#         0.07005960784313726, 0.07005960784313725, 0.07005960784313724],
#        ...,
#        [0.8064797110191259, 0.8095969319544013, 0.8097119114151287, ...,
#         0.7640196078474162, 0.7640196078471135, 0.7640196078389095],
#        [0.17944758861728746, 0.17794185539507396, 0.1798291785434648,
#         ..., 0.4588031678921569, 0.4616064767156862, 0.4593699571078432],
#        [0.4315834803921569, 0.43158348039215694, 0.4315834803921569, ...,
#         0.6518963020833334, 0.6518963020833334, 0.6518963020833334]],
#       dtype=object)

# %%
y
# Out:
# array(['kamal', 'rahman', 'kamal', 'rahman', 'kamal', 'rahman', 'kamal',
#        'kamal', 'rahman', 'kamal', 'rahman', 'kamal', 'kamal', 'rahman',
#        'kamal', 'rahman', 'kamal', 'rahman', 'rahman', 'kamal', 'kamal',
#        'kamal', 'kamal', 'kamal', 'kamal', 'kamal', 'kamal', 'kamal',
#        'rahman', 'kamal'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm

# %%
clf=svm.SVC()

# %%
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)
y_pred
# Out:
# array(['kamal', 'kamal', 'kamal', 'kamal', 'kamal', 'kamal'], dtype=object)

# %%
for i in (np.random.randint(0,6,4)):
    predicted_images=(np.reshape(x_test[i],(512,512)).astype(np.float64))
    plt.title('predicted label:{0}'.format(y_pred[i]))
    plt.imshow(predicted_images,interpolation='nearest',cmap='gray')
    plt.show()

# %%
from sklearn import metrics

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.5

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[3, 0],
#        [3, 0]], dtype=int64)
